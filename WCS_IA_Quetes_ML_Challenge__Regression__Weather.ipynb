# %% [markdown]
# <a href="https://colab.research.google.com/github/lugsantistebanji/WCS-IA/blob/main/WCS_IA_Quetes_ML_Challenge__Regression__Weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliothèques

# %%
import pandas as pd
import numpy as np
link_main = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather_main_2018.csv"
link_opinion = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather_opinion_2018.csv"
df_main = pd.read_csv(link_main)
df_opinion = pd.read_csv(link_opinion)

# %%
df_main.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0  2018-01-01                 12                  8                 61
# 1  2018-01-02                 13                  6                 26
# 2  2018-01-03                 15                 10                 40
# 3  2018-01-04                 14                 11                 45
# 4  2018-01-05                 12                  7                 21
#
#    TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                      9                  11                      8
# 1                      8                  12                     13
# 2                     11                  12                     10
# 3                     14                  14                     11
# 4                     10                  11                      8
#
#    PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  \
# 0                  8.9                    79              9.500
# 1                  0.6                    96              9.000
# 2                  5.5                    82              8.500
# 3                  0.0                    89             10.000
# 4                  1.5                    85              9.875
#
#    PRESSURE_MAX_MB  CLOUDCOVER_AVG_PERCENT  HEATINDEX_MAX_C  DEWPOINT_MAX_C  \
# 0             1018                  41.750               12               8
# 1             1020                  87.875               13              12
# 2             1017                  91.500               15              13
# 3             1011                  90.125               14              12
# 4             1005                  62.375               12              10
#
#    WINDTEMP_MAX_C
# 0               7
# 1               6
# 2               7
# 3              10
# 4               7

# %%
df_opinion.sort_values('date').head()
# Out:
#           date  WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR OPINION
# 0   2018-01-01                   113              0         3      5.1     bad
# 76  2018-01-02                   122              0         3      3.3     bad
# 69  2018-01-03                   122              0         3      3.3     bad
# 59  2018-01-04                   116              0         3      3.3     bad
# 60  2018-01-05                   116              0         3      6.9     bad

# %% [markdown]
# # Merge
# First of all, you have to merge both DataFrames to have a new DataFrame "df2018" DataFrame with 365 rows and 20 columns (indeed, you can drop the date column in double).

# %%
# Your code here :

df_weather = pd.merge(left=df_main, right=df_opinion, how="left", left_on='DATE', right_on='date').drop(['date'], axis=1)

df_weather.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0  2018-01-01                 12                  8                 61
# 1  2018-01-02                 13                  6                 26
# 2  2018-01-03                 15                 10                 40
# 3  2018-01-04                 14                 11                 45
# 4  2018-01-05                 12                  7                 21
#
#    TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                      9                  11                      8
# 1                      8                  12                     13
# 2                     11                  12                     10
# 3                     14                  14                     11
# 4                     10                  11                      8
#
#    PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  \
# 0                  8.9                    79              9.500
# 1                  0.6                    96              9.000
# 2                  5.5                    82              8.500
# 3                  0.0                    89             10.000
# 4                  1.5                    85              9.875
#
#    PRESSURE_MAX_MB  CLOUDCOVER_AVG_PERCENT  HEATINDEX_MAX_C  DEWPOINT_MAX_C  \
# 0             1018                  41.750               12               8
# 1             1020                  87.875               13              12
# 2             1017                  91.500               15              13
# 3             1011                  90.125               14              12
# 4             1005                  62.375               12              10
#
#    WINDTEMP_MAX_C  WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR  \
# 0               7                 113.0            0.0       3.0      5.1
# 1               6                 122.0            0.0       3.0      3.3
# 2               7                 122.0            0.0       3.0      3.3
# 3              10                 116.0            0.0       3.0      3.3
# 4               7                 116.0            0.0       3.0      6.9
#
#   OPINION
# 0     bad
# 1     bad
# 2     bad
# 3     bad
# 4     bad

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE                    365 non-null    object
#  1   MAX_TEMPERATURE_C       365 non-null    int64
#  2   MIN_TEMPERATURE_C       365 non-null    int64
#  3   WINDSPEED_MAX_KMH       365 non-null    int64
#  4   TEMPERATURE_MORNING_C   365 non-null    int64
#  5   TEMPERATURE_NOON_C      365 non-null    int64
#  6   TEMPERATURE_EVENING_C   365 non-null    int64
#  7   PRECIP_TOTAL_DAY_MM     365 non-null    float64
#  8   HUMIDITY_MAX_PERCENT    365 non-null    int64
#  9   VISIBILITY_AVG_KM       365 non-null    float64
#  10  PRESSURE_MAX_MB         365 non-null    int64
#  11  CLOUDCOVER_AVG_PERCENT  365 non-null    float64
#  12  HEATINDEX_MAX_C         365 non-null    int64
#  13  DEWPOINT_MAX_C          365 non-null    int64
#  14  WINDTEMP_MAX_C          365 non-null    int64
#  15  WEATHER_CODE_EVENING    341 non-null    float64
#  16  TOTAL_SNOW_MM           341 non-null    float64
#  17  UV_INDEX                341 non-null    float64
#  18  SUNHOUR                 341 non-null    float64
#  19  OPINION                 341 non-null    object
# dtypes: float64(7), int64(11), object(2)
# memory usage: 57.2+ KB

# %% [markdown]
# # Linear regresssion
# There are some missing values in the "Sunhour" column, and you want to fill them.
#
# First, you have to split the DataFrame to have :
# - a DF with only rows without NaN, you'll call it "df_clean". This DF should have 341 rows and 20 columns.
# - a DF with only rows with NaN in the Sunhour column (The rows you want to fill), you'll call it "df_nan". This DF should have 24 rows and 20 columns.

# %%
# Your code here :

df_clean = df_weather.dropna().copy()
df_nan = df_weather[df_weather.isna().any(axis=1)].copy()
df_nan
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 18   2018-01-19                 10                  6                 23
# 31   2018-02-01                  8                  3                 17
# 66   2018-03-08                 13                  7                 23
# 100  2018-04-11                 15                  7                 14
# 118  2018-04-29                 10                  7                 23
# 143  2018-05-24                 23                 12                  8
# 152  2018-06-02                 23                 12                  5
# 163  2018-06-13                 20                 12                 10
# 165  2018-06-15                 19                 13                 16
# 175  2018-06-25                 25                 13                 22
# 184  2018-07-04                 25                 16                 15
# 191  2018-07-11                 23                 14                 17
# 194  2018-07-14                 28                 16                 13
# 197  2018-07-17                 23                 16                 10
# 204  2018-07-24                 29                 18                 15
# 220  2018-08-09                 20                 14                 23
# 225  2018-08-14                 23                 14                 15
# 234  2018-08-23                 23                 16                 18
# 266  2018-09-24                 18                  7                 23
# 317  2018-11-14                 15                  7                 16
# 321  2018-11-18                  9                  4                 27
# 325  2018-11-22                 12                  2                 16
# 346  2018-12-13                  3                  2                 23
# 349  2018-12-16                 12                  7                 23
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 18                       6                  10                      6
# 31                       4                   8                      4
# 66                       7                  12                      9
# 100                      7                  15                     12
# 118                      8                  10                      8
# 143                     14                  22                     21
# 152                     15                  23                     21
# 163                     13                  20                     19
# 165                     14                  19                     18
# 175                     15                  24                     24
# 184                     18                  24                     21
# 191                     14                  23                     22
# 194                     18                  27                     26
# 197                     17                  22                     21
# 204                     20                  29                     24
# 220                     15                  20                     18
# 225                     14                  22                     21
# 234                     16                  22                     21
# 266                      7                  17                     13
# 317                      7                  15                     12
# 321                      4                   9                      6
# 325                      3                  10                      8
# 346                      3                   3                      2
# 349                      7                  12                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  \
# 18                   0.7                    88              9.875
# 31                   0.2                    81             10.000
# 66                   0.4                    87              9.750
# 100                  1.2                    87              7.875
# 118                  0.7                    93              9.000
# 143                  1.4                    81              7.875
# 152                  1.0                    75              9.875
# 163                  0.3                    72              9.000
# 165                  0.1                    85              8.000
# 175                  0.0                    71             10.000
# 184                  0.0                    74              7.750
# 191                  0.0                    70             10.000
# 194                  0.0                    66             10.000
# 197                  0.0                    66              8.000
# 204                  0.0                    59             10.000
# 220                  0.5                    75             10.000
# 225                  0.0                    71              7.000
# 234                  0.0                    70             10.000
# 266                  0.0                    58             10.000
# 317                  0.0                    83              9.000
# 321                  0.0                    77             10.000
# 325                  0.8                    90              9.625
# 346                  1.4                    86              8.875
# 349                  1.6                    91             10.000
#
#      PRESSURE_MAX_MB  CLOUDCOVER_AVG_PERCENT  HEATINDEX_MAX_C  DEWPOINT_MAX_C  \
# 18              1020                  37.000               10               6
# 31              1012                  39.500                8               3
# 66              1005                  52.625               13               7
# 100             1002                  59.125               15              10
# 118             1008                  85.000               10               9
# 143             1018                  27.250               25              17
# 152             1021                  24.750               25              18
# 163             1020                  36.875               21              16
# 165             1019                  61.625               19              15
# 175             1023                   4.750               26              19
# 184             1017                  41.125               26              17
# 191             1020                  10.500               25              16
# 194             1020                  14.000               28              18
# 197             1020                  40.625               25              16
# 204             1016                  15.375               30              18
# 220             1023                  29.750               20              14
# 225             1022                  35.250               25              17
# 234             1019                  43.500               25              17
# 266             1036                   1.625               18               7
# 317             1027                  22.000               16              13
# 321             1018                   0.375                9               3
# 325             1014                  44.500               12               8
# 346             1014                  88.875                3               1
# 349             1015                  48.375               12               7
#
#      WINDTEMP_MAX_C  WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR  \
# 18                5                   NaN            NaN       NaN      NaN
# 31                2                   NaN            NaN       NaN      NaN
# 66                6                   NaN            NaN       NaN      NaN
# 100              10                   NaN            NaN       NaN      NaN
# 118               7                   NaN            NaN       NaN      NaN
# 143              19                   NaN            NaN       NaN      NaN
# 152              20                   NaN            NaN       NaN      NaN
# 163              18                   NaN            NaN       NaN      NaN
# 165              16                   NaN            NaN       NaN      NaN
# 175              20                   NaN            NaN       NaN      NaN
# 184              22                   NaN            NaN       NaN      NaN
# 191              19                   NaN            NaN       NaN      NaN
# 194              23                   NaN            NaN       NaN      NaN
# 197              21                   NaN            NaN       NaN      NaN
# 204              27                   NaN            NaN       NaN      NaN
# 220              18                   NaN            NaN       NaN      NaN
# 225              20                   NaN            NaN       NaN      NaN
# 234              22                   NaN            NaN       NaN      NaN
# 266              12                   NaN            NaN       NaN      NaN
# 317               8                   NaN            NaN       NaN      NaN
# 321               1                   NaN            NaN       NaN      NaN
# 325               2                   NaN            NaN       NaN      NaN
# 346              -3                   NaN            NaN       NaN      NaN
# 349               6                   NaN            NaN       NaN      NaN
#
#     OPINION
# 18      NaN
# 31      NaN
# 66      NaN
# 100     NaN
# 118     NaN
# 143     NaN
# 152     NaN
# 163     NaN
# 165     NaN
# 175     NaN
# 184     NaN
# 191     NaN
# 194     NaN
# 197     NaN
# 204     NaN
# 220     NaN
# 225     NaN
# 234     NaN
# 266     NaN
# 317     NaN
# 321     NaN
# 325     NaN
# 346     NaN
# 349     NaN

# %% [markdown]
# ## Now, train your model
# For this part, let's work on df_clean.
# With scikit-learn, find the multivariate linear regression model with the best score (remember to train-test-split your DataFrame "df_clean" before!).
#
# You are trying to predict `SUNHOUR`, so what's your target `y` ?
#
# Print the R2-score for the test set, and check if you don't have underfitting or overfitting.

# %%
# Your code here
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


df_clean.columns
# Out:
# Index(['DATE', 'MAX_TEMPERATURE_C', 'MIN_TEMPERATURE_C', 'WINDSPEED_MAX_KMH',
#        'TEMPERATURE_MORNING_C', 'TEMPERATURE_NOON_C', 'TEMPERATURE_EVENING_C',
#        'PRECIP_TOTAL_DAY_MM', 'HUMIDITY_MAX_PERCENT', 'VISIBILITY_AVG_KM',
#        'PRESSURE_MAX_MB', 'CLOUDCOVER_AVG_PERCENT', 'HEATINDEX_MAX_C',
#        'DEWPOINT_MAX_C', 'WINDTEMP_MAX_C', 'WEATHER_CODE_EVENING',
#        'TOTAL_SNOW_MM', 'UV_INDEX', 'SUNHOUR', 'OPINION'],
#       dtype='object')

# %%
X = df_clean[['MAX_TEMPERATURE_C', 'MIN_TEMPERATURE_C', 'WINDSPEED_MAX_KMH',
       'TEMPERATURE_MORNING_C', 'TEMPERATURE_NOON_C', 'TEMPERATURE_EVENING_C',
       'PRECIP_TOTAL_DAY_MM', 'HUMIDITY_MAX_PERCENT', 'VISIBILITY_AVG_KM',
       'PRESSURE_MAX_MB', 'CLOUDCOVER_AVG_PERCENT', 'HEATINDEX_MAX_C',
       'DEWPOINT_MAX_C', 'WINDTEMP_MAX_C']]
y = df_clean['SUNHOUR']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size = 0.85)

model = LinearRegression().fit(X_train, y_train)

print("\nScore for the Train dataset :", model.score(X_train, y_train))
print("Score for the Test dataset :", model.score(X_test, y_test))
# Out:
# Score for the Train dataset : 0.7360262529728447
# Score for the Test dataset : 0.7281725419048481

# %% [markdown]
# ## Predictions
# Predict the sunhours values for your DF "df_nan", and store result in the `SUNHOUR` column (which is empty, because this is `df_nan`).

# %%
# Your code here
X_nan = df_nan[['MAX_TEMPERATURE_C', 'MIN_TEMPERATURE_C', 'WINDSPEED_MAX_KMH',
       'TEMPERATURE_MORNING_C', 'TEMPERATURE_NOON_C', 'TEMPERATURE_EVENING_C',
       'PRECIP_TOTAL_DAY_MM', 'HUMIDITY_MAX_PERCENT', 'VISIBILITY_AVG_KM',
       'PRESSURE_MAX_MB', 'CLOUDCOVER_AVG_PERCENT', 'HEATINDEX_MAX_C',
       'DEWPOINT_MAX_C', 'WINDTEMP_MAX_C']]

df_nan['SUNHOUR'] = model.predict(X_nan)

df_nan
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 18   2018-01-19                 10                  6                 23
# 31   2018-02-01                  8                  3                 17
# 66   2018-03-08                 13                  7                 23
# 100  2018-04-11                 15                  7                 14
# 118  2018-04-29                 10                  7                 23
# 143  2018-05-24                 23                 12                  8
# 152  2018-06-02                 23                 12                  5
# 163  2018-06-13                 20                 12                 10
# 165  2018-06-15                 19                 13                 16
# 175  2018-06-25                 25                 13                 22
# 184  2018-07-04                 25                 16                 15
# 191  2018-07-11                 23                 14                 17
# 194  2018-07-14                 28                 16                 13
# 197  2018-07-17                 23                 16                 10
# 204  2018-07-24                 29                 18                 15
# 220  2018-08-09                 20                 14                 23
# 225  2018-08-14                 23                 14                 15
# 234  2018-08-23                 23                 16                 18
# 266  2018-09-24                 18                  7                 23
# 317  2018-11-14                 15                  7                 16
# 321  2018-11-18                  9                  4                 27
# 325  2018-11-22                 12                  2                 16
# 346  2018-12-13                  3                  2                 23
# 349  2018-12-16                 12                  7                 23
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 18                       6                  10                      6
# 31                       4                   8                      4
# 66                       7                  12                      9
# 100                      7                  15                     12
# 118                      8                  10                      8
# 143                     14                  22                     21
# 152                     15                  23                     21
# 163                     13                  20                     19
# 165                     14                  19                     18
# 175                     15                  24                     24
# 184                     18                  24                     21
# 191                     14                  23                     22
# 194                     18                  27                     26
# 197                     17                  22                     21
# 204                     20                  29                     24
# 220                     15                  20                     18
# 225                     14                  22                     21
# 234                     16                  22                     21
# 266                      7                  17                     13
# 317                      7                  15                     12
# 321                      4                   9                      6
# 325                      3                  10                      8
# 346                      3                   3                      2
# 349                      7                  12                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  \
# 18                   0.7                    88              9.875
# 31                   0.2                    81             10.000
# 66                   0.4                    87              9.750
# 100                  1.2                    87              7.875
# 118                  0.7                    93              9.000
# 143                  1.4                    81              7.875
# 152                  1.0                    75              9.875
# 163                  0.3                    72              9.000
# 165                  0.1                    85              8.000
# 175                  0.0                    71             10.000
# 184                  0.0                    74              7.750
# 191                  0.0                    70             10.000
# 194                  0.0                    66             10.000
# 197                  0.0                    66              8.000
# 204                  0.0                    59             10.000
# 220                  0.5                    75             10.000
# 225                  0.0                    71              7.000
# 234                  0.0                    70             10.000
# 266                  0.0                    58             10.000
# 317                  0.0                    83              9.000
# 321                  0.0                    77             10.000
# 325                  0.8                    90              9.625
# 346                  1.4                    86              8.875
# 349                  1.6                    91             10.000
#
#      PRESSURE_MAX_MB  CLOUDCOVER_AVG_PERCENT  HEATINDEX_MAX_C  DEWPOINT_MAX_C  \
# 18              1020                  37.000               10               6
# 31              1012                  39.500                8               3
# 66              1005                  52.625               13               7
# 100             1002                  59.125               15              10
# 118             1008                  85.000               10               9
# 143             1018                  27.250               25              17
# 152             1021                  24.750               25              18
# 163             1020                  36.875               21              16
# 165             1019                  61.625               19              15
# 175             1023                   4.750               26              19
# 184             1017                  41.125               26              17
# 191             1020                  10.500               25              16
# 194             1020                  14.000               28              18
# 197             1020                  40.625               25              16
# 204             1016                  15.375               30              18
# 220             1023                  29.750               20              14
# 225             1022                  35.250               25              17
# 234             1019                  43.500               25              17
# 266             1036                   1.625               18               7
# 317             1027                  22.000               16              13
# 321             1018                   0.375                9               3
# 325             1014                  44.500               12               8
# 346             1014                  88.875                3               1
# 349             1015                  48.375               12               7
#
#      WINDTEMP_MAX_C  WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX    SUNHOUR  \
# 18                5                   NaN            NaN       NaN   7.421099
# 31                2                   NaN            NaN       NaN   8.203958
# 66                6                   NaN            NaN       NaN   7.605083
# 100              10                   NaN            NaN       NaN   9.695692
# 118               7                   NaN            NaN       NaN   6.307747
# 143              19                   NaN            NaN       NaN  13.983214
# 152              20                   NaN            NaN       NaN  14.021974
# 163              18                   NaN            NaN       NaN  12.682602
# 165              16                   NaN            NaN       NaN  10.203142
# 175              20                   NaN            NaN       NaN  15.530864
# 184              22                   NaN            NaN       NaN  12.323529
# 191              19                   NaN            NaN       NaN  14.315719
# 194              23                   NaN            NaN       NaN  14.920293
# 197              21                   NaN            NaN       NaN  12.593232
# 204              27                   NaN            NaN       NaN  14.462791
# 220              18                   NaN            NaN       NaN  11.471129
# 225              20                   NaN            NaN       NaN  12.889456
# 234              22                   NaN            NaN       NaN  11.010974
# 266              12                   NaN            NaN       NaN  10.644629
# 317               8                   NaN            NaN       NaN  10.408559
# 321               1                   NaN            NaN       NaN  11.085479
# 325               2                   NaN            NaN       NaN   7.681012
# 346              -3                   NaN            NaN       NaN   4.534757
# 349               6                   NaN            NaN       NaN   7.364176
#
#     OPINION
# 18      NaN
# 31      NaN
# 66      NaN
# 100     NaN
# 118     NaN
# 143     NaN
# 152     NaN
# 163     NaN
# 165     NaN
# 175     NaN
# 184     NaN
# 191     NaN
# 194     NaN
# 197     NaN
# 204     NaN
# 220     NaN
# 225     NaN
# 234     NaN
# 266     NaN
# 317     NaN
# 321     NaN
# 325     NaN
# 346     NaN
# 349     NaN

# %% [markdown]
# ## Concatenate and scatterplot
#
# Concatenate both DataFrames to a new one "df2018complete", and draw a scatterplot with Date on X-axis and Sunhours on Y-axis.
# Try to add a flag to identify real values and predicted values.
#
# You should get something like that. Of course, not exactly the same chart, because we don't train the same model, on the same columns, etc...
#
# ![Capture d’écran 2020-11-04 à 09.37.57.png](data:image/png;base64,...)

# %%
# Your code here
import matplotlib.pyplot as plt
import seaborn as sns


df_clean['flag'] = "real values"
df_nan['flag'] = "predicted values"

df2018complete = pd.concat([df_clean, df_nan])

df2018complete['DATE'] = pd.to_datetime(df2018complete['DATE'])

sns.scatterplot(x=df2018complete['DATE'], y=df2018complete['SUNHOUR'], hue=df2018complete['flag'])

plt.show()
