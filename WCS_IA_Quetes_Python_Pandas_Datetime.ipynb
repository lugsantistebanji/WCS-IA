# %% [markdown]
# <a href="https://colab.research.google.com/github/lugsantistebanji/WCS-IA/blob/main/WCS_IA_Quetes_Python_Pandas_Datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Your mission: convert each string variable into datetime objects

# %%
var1 = '2018-01-04'
print(type(var1))
print(var1)
# Out:
# <class 'str'>
# 2018-01-04

# %%
# It's up to you :
var_date = datetime.strptime(var1, '%Y-%m-%d')
print(var_date)
print(type(var_date))
# Out:
# 2018-01-04 00:00:00
# <class 'datetime.datetime'>

# %%
var2 = '14/02/2019'
# It's up to you :
var_date2 = datetime.strptime(var2, "%d/%m/%Y")
print(var_date2)
# Out:
# 2019-02-14 00:00:00

# %%
var3 = '14 03 20'
# It's up to you :
var_date3 = datetime.strptime(var3, "%d %m %y")
print(var_date3)
# Out:
# 2020-03-14 00:00:00

# %%
var4 = '14/02/2019 21:30'
# It's up to you :
var_date4 = datetime.strptime(var4, "%d/%m/%Y %H:%M")
print(var_date4)
# Out:
# 2019-02-14 21:30:00

# %%
var5 = '2018-01-04 at 18 hours and 48 min'
# It's up to you :
var_date5 = datetime.strptime(var5, "%Y-%m-%d at %H hours and %M min")
print(var_date5)
# Out:
# 2018-01-04 18:48:00

# %% [markdown]
# # Your mission: convert the datetime object into string with precise format

# %%
var_date = datetime.strptime('2020-02-15 20:05', '%Y-%m-%d %H:%M')
print(var_date)
# Out:
# 2020-02-15 20:05:00

# %%
# We would like to print this format : 15/02/2020
var_date_str1 = var_date.strftime("%d/%m/%Y")
print(var_date_str1)
# Out:
# 15/02/2020

# %%
# We would like to print this format : 15-02-2020
var_date_str2 = var_date.strftime("%d-%m-%Y")
print(var_date_str2)
# Out:
# 15-02-2020

# %%
# We would like to print this format : 15/02
var_date_str3 = var_date.strftime("%d/%m")
print(var_date_str3)
# Out:
# 15/02

# %%
# We would like to print this format : 2020-02
var_date_str4 = var_date.strftime("%Y-%m")
print(var_date_str4)
# Out:
# 2020-02

# %%
# We would like to print this format : 2020-02-15 at 20:05
var_date_str5 = var_date.strftime("%Y-%m-%d at %H:%M")
print(var_date_str5)
# Out:
# 2020-02-15 at 20:05

# %% [markdown]
# # Your mission is to determine which date it was / it will be

# %%
# what month will it be in 7 weeks ?
date_now_plus_7_weeks = datetime.now() + timedelta(weeks=7)
print(date_now_plus_7_weeks.strftime("%B"))
# Out:
# February

# %%
# what day of the week will it be in 3 days ?
date_now_plus_3_days = datetime.now() + timedelta(days=3)
print(date_now_plus_3_days.strftime("%A"))
# Out:
# Thursday

# %%
# what hour will it be in 100 hours ?
date_now_plus_100_hours = datetime.now() + timedelta(hours=100)
print(date_now_plus_100_hours.hour)
# Out:
# 14

# %%
# what date was 30 days ago ?
date_30_days_ago = datetime.now() - timedelta(days=30)
print(date_30_days_ago.strftime("%d/%m/%Y"))
# Out:
# 16/11/2024

# %%
# what date was 30 weeks ago ?
date_30_weeks_ago = datetime.now() - timedelta(weeks=30)
print(date_30_weeks_ago.strftime("%d/%m/%Y"))
# Out:
# 20/05/2024

# %% [markdown]
# # With Pandas
# "DATE" column has only string values. On a chart, the X-axis is not well displayed.

# %%
# Please run this cell without modification:
df = pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv")
fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'],
           y=df['MAX_TEMPERATURE_C'])
fig.show()

# %%
# Convert the "DATE" column into a datetime format, then display the same chart. Are ticks on X-axis better printed ?
df['DATE'] = pd.to_datetime(df['DATE'])
fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'],
           y=df['MAX_TEMPERATURE_C'])
fig.show()

# %%
# Display only rows for the month of June
df_juin = df[df['DATE'].dt.month == 6]

print(df_juin.head(5))

fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df_juin['DATE'],
           y=df_juin['MAX_TEMPERATURE_C'])
fig.show()
# Out:
#           DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 151 2019-06-01                 29                 16                  9
# 152 2019-06-02                 23                 15                 17
# 153 2019-06-03                 20                 14                 14
# 154 2019-06-04                 19                 13                 25
# 155 2019-06-05                 16                 10                 15
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 151                     17                  27                     27
# 152                     19                  23                     20
# 153                     14                  19                     19
# 154                     14                  18                     18
# 155                     12                  16                     15
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 151                  0.0                    75             10.000  ...
# 152                  0.0                    72             10.000  ...
# 153                  0.5                    77              8.000  ...
# 154                  6.3                    87              9.375  ...
# 155                  1.5                    76              9.875  ...
#
#      WINDTEMP_MAX_C  WEATHER_CODE_MORNING  WEATHER_CODE_NOON  \
# 151              22                   116                113
# 152              21                   116                116
# 153              16                   266                116
# 154              17                   296                353
# 155              15                   116                176
#
#      WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  \
# 151                   113              0         1     14.5         very good
# 152                   119              0         1     13.5              good
# 153                   116              0         1     12.6              good
# 154                   122              0         1      9.7               bad
# 155                   176              0         1      9.7  not good not bad
#
#      MONTH  DAY
# 151      6    1
# 152      6    2
# 153      6    3
# 154      6    4
# 155      6    5
#
# [5 rows x 24 columns]
