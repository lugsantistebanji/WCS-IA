# %% [markdown]
# <a href="https://colab.research.google.com/github/lugsantistebanji/WCS-IA/blob/main/WCS_IA_Quetes_API_GeoCoding_with_Nominatim_OSM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
# Execute the code below :
import requests
from unidecode import unidecode


link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
    'Referer': 'https://www.example.com'
}
r = requests.get(link, headers=headers).json()
r
# Out:
# [{'place_id': 48174245,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1125079468,
#   'lat': '37.225196722061376',
#   'lon': '14.52468563676896',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339371862363619,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Caltagirone, Catania, Sicilia, 95041, Italia',
#   'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']},
#  {'place_id': 48194427,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'lat': '37.6091344949263',
#   'lon': '15.159672789802412',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.0533936133363851,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847']},
#  {'place_id': 48163343,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128394486,
#   'lat': '37.60904992059251',
#   'lon': '15.160658014765406',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.0533936133363851,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Santa Caterina, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6089805', '37.6091110', '15.1602847', '15.1610300']},
#  {'place_id': 48357481,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'lat': '37.56761682875522',
#   'lon': '14.910691326755646',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339132753490498,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Paternò, Catania, Sicilia, 95047, Italia',
#   'boundingbox': ['37.5673863', '37.5680619', '14.9106500', '14.9109837']},
#  {'place_id': 48156975,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1203329854,
#   'lat': '37.72424835872716',
#   'lon': '15.178990192995753',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053390183108262726,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia',
#   'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']},
#  {'place_id': 48506535,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 540088607,
#   'lat': '37.7871875257684',
#   'lon': '14.835660187034607',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053390039673456895,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Bronte, Catania, Sicilia, 95034, Italia',
#   'boundingbox': ['37.7871116', '37.7872091', '14.8351854', '14.8361387']},
#  {'place_id': 48076040,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 60574095,
#   'lat': '37.511279234228624',
#   'lon': '14.966745067050883',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.0533890646219577,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': "Via Pietro Mascagni, Motta Sant'Anastasia, Catania, Sicilia, 95040, Italia",
#   'boundingbox': ['37.5112226', '37.5117469', '14.9660373', '14.9678432']},
#  {'place_id': 48208497,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 340599607,
#   'lat': '37.21334249630256',
#   'lon': '14.634173248573026',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053389035629816096,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Grammichele, Catania, Sicilia, 95042, Italia',
#   'boundingbox': ['37.2132636', '37.2135294', '14.6341245', '14.6343514']},
#  {'place_id': 48018239,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 223112430,
#   'lat': '37.29698452576491',
#   'lon': '14.84153975368439',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.053388876935988365,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Scordia, Catania, Sicilia, 95048, Italia',
#   'boundingbox': ['37.2968575', '37.2971447', '14.8410915', '14.8419764']},
#  {'place_id': 48568747,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 211056073,
#   'lat': '37.556350800000004',
#   'lon': '14.917264549999999',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.05339132753490498,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Giaconia, Belpasso, Catania, Sicilia, 95032, Italia',
#   'boundingbox': ['37.5559895', '37.5567121', '14.9169673', '14.9175618']}]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 48174245, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1125079468, 'lat': '37.225196722061376', 'lon': '14.52468563676896', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05339371862363619, 'addresstype': 'road', 'name': 'Via Pietro Mascagni', 'display_name': 'Via Pietro Mascagni, Caltagirone, Catania, Sicilia, 95041, Italia', 'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']}
# First address longitude : 14.52468563676896
# First address latitude : 37.225196722061376

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link, headers=headers).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link, headers=headers).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character,
# and special characters or accents should be avoided if possible

link_main = 'https://nominatim.openstreetmap.org/?q='
address = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'

link = link_main + address.replace(", ",",").replace(" ", "+")
print(link + link_end)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1

# %%
def get_url_with_address_normalized(adresse_postale):
    link_main = 'https://nominatim.openstreetmap.org/?q='
    adress = adresse_postale.replace(", ",",").replace(" ", "+")
    link_end = '&format=json&limit=1'
    link = link_main + adress + link_end
    return link

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API,
# then makes the request and returns the coordinates :

def API_address(adresse_postale):
    coordinates = []
    link = get_url_with_address_normalized(adresse_postale)
    response = requests.get(link, headers=headers)

    if response.status_code == 200:
        data = response.json()
        coordinates = (data[0]['lat'], data[0]['lon'])
    else:
        print(f"Request error : {response.status_code}")

    return tuple(coordinates)

# %%
# Test it here:
API_address(address)
# Out:
# ('37.225196722061376', '14.52468563676896')

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3319d2edee5f3e701149f315373ea889 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3319d2edee5f3e701149f315373ea889&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3319d2edee5f3e701149f315373ea889 = L.map(
#                 &quot;map_3319d2edee5f3e701149f315373ea889&quot;,
#                 {
#                     center: [37.225196722061376, 14.52468563676896],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_447e20bfe26db94bc31692601ac490aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_447e20bfe26db94bc31692601ac490aa.addTo(map_3319d2edee5f3e701149f315373ea889);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f1d2455449cfa3da70beb0ce1c86ef4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f1d2455449cfa3da70beb0ce1c86ef4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f1d2455449cfa3da70beb0ce1c86ef4 = L.map(
#                 &quot;map_6f1d2455449cfa3da70beb0ce1c86ef4&quot;,
#                 {
#                     center: [37.225196722061376, 14.52468563676896],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9a920eac84c18737c146e2c8f18cec3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9a920eac84c18737c146e2c8f18cec3.addTo(map_6f1d2455449cfa3da70beb0ce1c86ef4);
#
#
#             var marker_526b919b7fd2fa231ead0c79db89fd58 = L.marker(
#                 [37.225196722061376, 14.52468563676896],
#                 {
# }
#             ).addTo(map_6f1d2455449cfa3da70beb0ce1c86ef4);
#
#
#         var popup_69c41f47b4983781e1586b188425c902 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_559b44595eb68784df2ff557ec62c118 = $(`&lt;div id=&quot;html_559b44595eb68784df2ff557ec62c118&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#                 popup_69c41f47b4983781e1586b188425c902.setContent(html_559b44595eb68784df2ff557ec62c118);
#
#
#
#         marker_526b919b7fd2fa231ead0c79db89fd58.bindPopup(popup_69c41f47b4983781e1586b188425c902)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %% [markdown]
# 1. __DataFrame__

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])

restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %% [markdown]
# 2. __Fetching coordinates__

# %%
restaurants['coordinates'] = restaurants['address'].apply(API_address)

# %%
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                                coordinates
# 0                 (37.5020931, 15.0931951)
# 1                  (37.506171, 15.0943223)
# 2  (37.48944028886065, 15.079431220911957)
# 3                 (37.5029335, 15.0930406)

# %% [markdown]
# 3. __Display map__

# %%
import folium

mapp = folium.Map(location=restaurants.loc[0,'coordinates'], zoom_start=14)

for index, restaurant in restaurants.iterrows():
    folium.Marker(
    location=restaurant['coordinates'],
    popup=f"{restaurant['name']} - \n{restaurant['address']} - \n{restaurant['coordinates']}"
    ).add_to(mapp)
mapp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b474d909bbeaa6276d589366d3b595c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b474d909bbeaa6276d589366d3b595c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b474d909bbeaa6276d589366d3b595c8 = L.map(
#                 &quot;map_b474d909bbeaa6276d589366d3b595c8&quot;,
#                 {
#                     center: [37.5020931, 15.0931951],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dd72f8730acb5a6536104be6827fde8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8dd72f8730acb5a6536104be6827fde8.addTo(map_b474d909bbeaa6276d589366d3b595c8);
#
#
#             var marker_23546738b24e3bcce2eaf6a8b458c663 = L.marker(
#                 [37.5020931, 15.0931951],
#                 {
# }
#             ).addTo(map_b474d909bbeaa6276d589366d3b595c8);
#
#
#         var popup_601eb32629638864d4954c69a1960d03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ea8c3a7d496d487636b924e0b882490 = $(`&lt;div id=&quot;html_8ea8c3a7d496d487636b924e0b882490&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964 -  Via Porta di Ferro, 47, 95131 Catania CT -  (&#x27;37.5020931&#x27;, &#x27;15.0931951&#x27;)&lt;/div&gt;`)[0];
#                 popup_601eb32629638864d4954c69a1960d03.setContent(html_8ea8c3a7d496d487636b924e0b882490);
#
#
#
#         marker_23546738b24e3bcce2eaf6a8b458c663.bindPopup(popup_601eb32629638864d4954c69a1960d03)
#         ;
#
#
#
#
#             var marker_777a81eef6d054a0a585f7657dbeece1 = L.marker(
#                 [37.506171, 15.0943223],
#                 {
# }
#             ).addTo(map_b474d909bbeaa6276d589366d3b595c8);
#
#
#         var popup_7d62f70a630bc6ba75adf658b0fa13e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62a5d4f3bfd64d035d8b5d233a07964e = $(`&lt;div id=&quot;html_62a5d4f3bfd64d035d8b5d233a07964e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici -  Via Fischetti, 14, 95131 Catania CT -  (&#x27;37.506171&#x27;, &#x27;15.0943223&#x27;)&lt;/div&gt;`)[0];
#                 popup_7d62f70a630bc6ba75adf658b0fa13e7.setContent(html_62a5d4f3bfd64d035d8b5d233a07964e);
#
#
#
#         marker_777a81eef6d054a0a585f7657dbeece1.bindPopup(popup_7d62f70a630bc6ba75adf658b0fa13e7)
#         ;
#
#
#
#
#             var marker_7d8e84ea57cfdb738ef76def2f44ab79 = L.marker(
#                 [37.48944028886065, 15.079431220911957],
#                 {
# }
#             ).addTo(map_b474d909bbeaa6276d589366d3b595c8);
#
#
#         var popup_7719a2c7df1f1e9fd68d3d40fb0cfd3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8a2e47ee9bcbc39640a11b52b1e324e = $(`&lt;div id=&quot;html_d8a2e47ee9bcbc39640a11b52b1e324e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta -  Via Acquicella Porto, 95121 Catania CT -  (&#x27;37.48944028886065&#x27;, &#x27;15.079431220911957&#x27;)&lt;/div&gt;`)[0];
#                 popup_7719a2c7df1f1e9fd68d3d40fb0cfd3e.setContent(html_d8a2e47ee9bcbc39640a11b52b1e324e);
#
#
#
#         marker_7d8e84ea57cfdb738ef76def2f44ab79.bindPopup(popup_7719a2c7df1f1e9fd68d3d40fb0cfd3e)
#         ;
#
#
#
#
#             var marker_933bd53f2e7036eae76b99fa64030d2e = L.marker(
#                 [37.5029335, 15.0930406],
#                 {
# }
#             ).addTo(map_b474d909bbeaa6276d589366d3b595c8);
#
#
#         var popup_b8fc194566e07448ff45394311198ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2564174aae98093ade4c4917dabb76 = $(`&lt;div id=&quot;html_8a2564174aae98093ade4c4917dabb76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House -  Via Porta di Ferro, 8, 95100 Catania CT -  (&#x27;37.5029335&#x27;, &#x27;15.0930406&#x27;)&lt;/div&gt;`)[0];
#                 popup_b8fc194566e07448ff45394311198ce6.setContent(html_8a2564174aae98093ade4c4917dabb76);
#
#
#
#         marker_933bd53f2e7036eae76b99fa64030d2e.bindPopup(popup_b8fc194566e07448ff45394311198ce6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Remarks on the Nominatim API
# As indicated in the quest, there are many resources for geocoding. Most of them are available by registration, and some require a fee.
#
# The Nominatim API is free and without registration. The disadvantage is that it is relatively slow. If you need to use it in the future, remember to store the results so you don't have to run it several times.
#
# For your knowledge, there is also :
# - the **reverse** address API, which allows you to find the nearest postal address using geographic coordinates.
# - the API from a **CSV file** if you have a lot of addresses to geocode
# - the API **GeoJSON** which allows to obtain a geoJSON format of locations to make choropleth maps
#
#
# All the [documentation is available here](https://nominatim.org/release-docs/develop/api/Search/).
